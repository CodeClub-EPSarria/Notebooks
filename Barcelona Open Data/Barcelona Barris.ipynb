# %%
# %matplotlib inline

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('/Users/polbaladas/Desktop/Code/Notebooks/Data/poblacio.csv', sep=',', encoding='utf8', index_col = "Barri")

# %%
print(data)
# Out:
#                                                   Habitants
# Barri
# 1. el Raval                                              48
# 2. el Barri Gòtic                                        16
# 3. la Barceloneta                                        15
# 4. Sant Pere, Santa Caterina i la Ribera                 23
# 5. el Fort Pienc                                         32
# 6. la Sagrada Família                                    52
# 7. la Dreta de l'Eixample                                44
# 8. l'Antiga Esquerra de l'Eixample                       42
# 9. la Nova Esquerra de l'Eixample                        58
# 10. Sant Antoni                                          38
# 11. el Poble Sec - AEI Parc Montjuïc                     41
# 12. la Marina del Prat Vermell - AEI Zona Franca          1
# 13. la Marina de Port                                    30
# 14. la Font de la Guatlla                                10
# 15. Hostafrancs                                          16
# ...

# %%
pd.set_option('display.mpl_style', 'default')
figsize(15, 5)
data['Habitants'].plot(kind="bar")
